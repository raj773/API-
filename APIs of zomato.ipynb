# %% [markdown]
# # Assignment

# %%
##api key:20bc0e62b4ae026ee7f54799960494d7

# %%
import requests
a=requests.get('https://developers.zomato.com/api/v2.1/cuisines?city_id=1',headers={'user-key': '20bc0e62b4ae026ee7f54799960494d7'})
data=a.json()
d=data['cuisines']
for i in d:
    if(i['cuisine']['cuisine_name']=='Mexican'):
        print(i['cuisine']['cuisine_id'])
# Out:
# 73

# %%
#"latitude": 28.632832,
#"longitude": 77.219688,
import requests
s={'query':'Connaught Place'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
h=requests.get('https://developers.zomato.com/api/v2.1/locations',params=s,headers=key)
data=h.json()
print(data['location_suggestions'][0]['entity_type'],data['location_suggestions'][0]['entity_id'])
# Out:
# subzone 104

# %%
import requests
s={'entity_id':'104','entity_type':'subzone','cuisines':'73','sort':'rating','order':'desc'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/search'
h=requests.get(k,params=s,headers=key)
data=h.json()
m=0
for i in data['restaurants']:
    if(m<10):
        print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'])
        m+=1
# Out:
# Farzi Cafe 4.5 18233593
# Chili's Grill & Bar 4.5 18537536
# Ministry Of Beer 4.4 18418277
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.3 18237315
# Unplugged Courtyard 4.2 18216901
# Pebble Street 4.2 309859
# The Beer Cafe - BIGGIE 4.2 307060
# Rodeo Cantina & Kitchen 4.1 18673403
# 38 Barracks 4.1 18241537

# %%
k='https://developers.zomato.com/api/v2.1/categories'

key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
h=requests.get(k,headers=key)
data=h.json()
for i in data['categories']:
    if(i['categories']['name']=='Cafes'):
        print(i['categories']['id'])
# Out:
# 6

# %%
import requests
s={'entity_id':'104','entity_type':'subzone','cuisines':'73','category':'6'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/search'
h=requests.get(k,params=s,headers=key)
data=h.json()
m=0
for i in data['restaurants']:
    
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'])
# Out:
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.3 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %%
import requests
s={'count':5,'res_id':18729557}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/reviews'
h=requests.get(k,params=s,headers=key)
data=h.json()
data1=data['user_reviews']
for i in data1:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Shubham Khurana 5 Zero Degree💯 This place in CP is all time fav place to go with buddies👫👌 U must try there fries😍 and cheesy nachos🧀 Amazing place with affordable proce and an amazing menu with nice presentation. Ambience is also good. There is usually rush in the areas as the capacity to hold the guest is very small still people wait in long queues just to eat at this cafe. The taste and the quality is just fantastic.  Highly recommend✅ cafe situated in Connaught place in Delhi.
# Shubham Khurana 5 Zero Degree💯 This place in CP is all time fav place to go with buddies👫👌 U must try there fries😍 and cheesy nachos🧀 Amazing place with affordable proce and an amazing menu with nice presentation. Ambience is also good. There is usually rush in the areas as the capacity to hold the guest is very small still people wait in long queues just to eat at this cafe. The taste and the quality is just fantastic.  Highly recommend✅ cafe situated in Connaught place in Delhi.
# ...

# %%
import requests
s={'res_id':18429148}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/restaurant'
h=requests.get(k,params=s,headers=key)
data=h.json()
print(data['user_rating']['aggregate_rating'])
print(data['average_cost_for_two'])
print(data['cuisines'])
print(data['location']['address'])
# Out:
# 4.9
# 2500
# Asian, Chinese, Thai, Japanese
# A-3, Select Citywalk, District Centre, Saket, New Delhi

# %%
import requests
s={'res_id':18429148}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/restaurant'
h=requests.get(k,params=s,headers=key)
data=h.json()
if(data['is_table_reservation_supported']):
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
import requests
s={'count':5,'res_id':18429148}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/reviews'
h=requests.get(k,params=s,headers=key)
data=h.json()
data1=data['user_reviews']
for i in data1:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Shweta Kumar 4
# Hungry Wolfs 5 This place serves amazing food the ambiance is super good you can go on dates chill out with friends and family kitty’s aswell
# Rushil Badhwar 4
# Anushri Tripathi 5
# TheProud_Glutton 5 The best place to try so many different types of dimsums😋

# %%
import requests
s={'city_id':"40"}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/cuisines'
h=requests.get(k,params=s,headers=key)
data=h.json()
d=data['cuisines']
for i in d:
    if(i['cuisine']['cuisine_name']=='BBQ'):
        print(i['cuisine']['cuisine_id'])
# Out:
# 193

# %%
import requests
s={'lat':28.697850,'lon':77.140670,'count':10,'cuisines':193,'sort':'real_distance','order':'asc'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/search'
h=requests.get(k,params=s,headers=key)
data=h.json()
d=data['restaurants']

for i in d:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.6 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.1 18889760 Rohini
# Kays Bar-Be-Que 3.9 3079 Ashok Vihar Phase 1
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# Hunger On Wheels 0 19054336 Vijay Nagar

# %%
import requests
s={'count':5,'res_id':18204820}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/reviews'
h=requests.get(k,params=s,headers=key)
data=h.json()
data1=data['user_reviews']
for i in data1:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Abhishek Sharma 5 Their buffet is definitely better than barbeque nation.
# Sakshi Sabnani 4 We organized a get together here..ambiance and drinks was good but the food was not upto the mark but if you are going for dine out the food is good..maybe they weren't able to cater the party well.
# ANNANT VASHIST 5 I celebrated my bday in Themis barbecue . I enjoyed a lot and the staff was really good nd the food is very delicious .
# ...

# %%
import requests
s={'lat':28.697850,'lon':77.140670,'count':10,'radius':4000,'sort':'rating'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/search'
h=requests.get(k,params=s,headers=key)
data=h.json()
d=data['restaurants']

for i in d:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Cafe Lota 4.9 305525 Pragati Maidan
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# The Big Chill 4.9 1614 Khan Market
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Natural Ice Cream 4.8 310143 Connaught Place

# %%
import requests
s={'lat':28.697850,'lon':77.140670,'count':10,'radius':4000,'sort':'rating'}
key={'user-key': '20bc0e62b4ae026ee7f54799960494d7'}
k='https://developers.zomato.com/api/v2.1/search?entity_id=1&entity_type=city&start=1&count=20 '
h=requests.get(k,params=s,headers=key)
data=h.json()
d=data['restaurants']

for i in d:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Cafe Lota 4.9 305525 Pragati Maidan
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# The Big Chill 4.9 1614 Khan Market
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Natural Ice Cream 4.8 310143 Connaught Place
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29

# %% [markdown]
# # Case study 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
Rest_of_ind=data[(data['City']!='New Delhi')&(data['City']!='Ghaziabad')&(data['City']!='Noida')&(data['City']!='Gurgaon')&(data['City']!='Faridabad')]

Delhi=data[(data['City']=='New Delhi')|(data['City']=='Ghaziabad')|(data['City']=='Noida')|(data['City']=='Gurgaon')|(data['City']=='Faridabad')]
count=[Rest_of_ind.shape[0],Delhi.shape[0]]
state=['Rest of India',"Delhi NCR"]

plt.bar(state,count)
plt.xlabel("State")
plt.ylabel("NO of Restaurant")
plt.title(' Delhi NCR vs Rest of India')
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
Rest_of_ind=data[(data['City']!='New Delhi')&(data['City']!='Ghaziabad')&(data['City']!='Noida')&(data['City']!='Gurgaon')&(data['City']!='Faridabad')]

Delhi=data[(data['City']=='New Delhi')|(data['City']=='Ghaziabad')|(data['City']=='Noida')|(data['City']=='Gurgaon')|(data['City']=='Faridabad')]

rest=Rest_of_ind["Cuisines"].str.split(",",expand=True)[1].str.strip()
delhi=Delhi["Cuisines"].str.split(",",expand=True)[1].str.strip()
x=pd.unique(rest)
y=pd.unique(delhi)

for i in x:
    if(i not in y):
        print(i)
# Out:
# Gujarati
# Charcoal Grill
# Goan
# German

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
Rest_of_ind=data[(data['City']!='New Delhi')&(data['City']!='Ghaziabad')&(data['City']!='Noida')&(data['City']!='Gurgaon')&(data['City']!='Faridabad')]

Delhi=data[(data['City']=='New Delhi')|(data['City']=='Ghaziabad')|(data['City']=='Noida')|(data['City']=='Gurgaon')|(data['City']=='Faridabad')]
rest=Rest_of_ind["Cuisines"].value_counts()
ncr=Delhi["Cuisines"].value_counts()
fre=rest.index[0:10]
fre2=ncr.index[0:10]
print("The top 10 cuisines served by maximum number of restaurants in Delhi NCR")
for i in fre2:
    print(i)
print("The top 10 cuisines served by maximum number of restaurants in Rest of India")
for i in fre:
    print(i)
# Out:
# The top 10 cuisines served by maximum number of restaurants in Delhi NCR
# North Indian
# North Indian, Chinese
# Fast Food
# Chinese
# North Indian, Mughlai
# Cafe
# Bakery
# North Indian, Mughlai, Chinese
# Bakery, Desserts
# Street Food
# The top 10 cuisines served by maximum number of restaurants in Rest of India
# North Indian, Chinese
# North Indian
# Cafe
# North Indian, Mughlai
# Fast Food
# Chinese
# North Indian, Chinese, Continental
# Cafe, Fast Food
# Pizza
# North Indian, Fast Food

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
Rest_of_ind=data[(data['City']!='New Delhi')&(data['City']!='Ghaziabad')&(data['City']!='Noida')&(data['City']!='Gurgaon')&(data['City']!='Faridabad')]

Delhi=data[(data['City']=='New Delhi')|(data['City']=='Ghaziabad')|(data['City']=='Noida')|(data['City']=='Gurgaon')|(data['City']=='Faridabad')]
rest=Rest_of_ind["Cuisines"].value_counts()
ncr=Delhi["Cuisines"].value_counts()
index=rest.index[0:10]
index2=ncr.index[0:10]

plt.title('Rest of India')
plt.pie(rest[0:10],labels=index,autopct="%.2f%%")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
Rest_of_ind=data[(data['City']!='New Delhi')&(data['City']!='Ghaziabad')&(data['City']!='Noida')&(data['City']!='Gurgaon')&(data['City']!='Faridabad')]

Delhi=data[(data['City']=='New Delhi')|(data['City']=='Ghaziabad')|(data['City']=='Noida')|(data['City']=='Gurgaon')|(data['City']=='Faridabad')]
rest=Rest_of_ind["Cuisines"].value_counts()
ncr=Delhi["Cuisines"].value_counts()
index=rest.index[0:10]
index2=ncr.index[0:10]

plt.title('Delhi NCR')
 
plt.pie(ncr[0:10],labels=index2,autopct="%.2f%%")

plt.show()

# %%
max_rate=zomato.sort_values('Aggregate rating', ascending=False).groupby(by=['Country Code','City'],as_index=False).first() #find the highest restuarant in the city 
min_rate=zomato.sort_values('Aggregate rating', ascending=False).groupby(by=['Country Code','City'],as_index=False).last() #find the lowest restuarant in the city 
df_max=max_rate[['Country Code','City','Restaurant Name','Aggregate rating']] #new dataframe created for low rated restaurants
df_min=min_rate[['Country Code','City','Restaurant Name','Aggregate rating']]#new dataframe created for high rated restaurants

rating_rest=df_max.merge(df_min,left_on='City',right_on='City',how='inner') #inner join to merge the two dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('zomato.csv',encoding='latin-1')

df['Aggregate_rating_Votes']=df['Aggregate rating']*df['Votes'] #making another column Aggregate_rating_Votes.
data=df.copy() #copy of data
top_10_locality=[]
top_10_weighted=[]
p=data.Locality.value_counts() #calculating value how many time came.
new_index = p.index #making new index of p values.
dic={}
for ele in new_index:
    d=data[data['Locality']==ele]
    total_result = d['Aggregate_rating_Votes'].sum()
    count= d['Votes'].sum()
    if count == 0: #if count zero then continue other wise total_result/count give error.
        continue
    weighted=total_result/count
    dic[ele]=weighted
i=1
for key,value in sorted(dic.items(), key=lambda kv: kv[1],reverse=True): # put the key,value pair from d in decreasing order of value
    top_10_locality.append(key)
    top_10_weighted.append(value)
    if i==10:
        break
    i=i+1
locality=top_10_locality #top 10 localties
Weighted_Restaurant_Rating=top_10_weighted #top 10 weighted_restaurant_rating.

#printing Data
print("------------------------------------------------------------------")
for e1, e2 in zip(locality,Weighted_Restaurant_Rating):
    print('{:<20s}|{:>11.8f}'.format(e1,e2))
print("------------------------------------------------------------------")
#plotting of Graph    
plt.subplots(figsize=(17,7))    
plt.bar(locality,Weighted_Restaurant_Rating)
plt.xticks(rotation=50)
plt.xlabel("Cuisine")
plt.ylabel("Weighted Restaurant Rating")
plt.title("Cuisine vs Weighted Restaurant Rating")
plt.show()
# Out:
# ------------------------------------------------------------------
# Nassima Royal Hotel, Trade Centre Area| 4.90000000
# DIFC                | 4.90000000
# Pondok Aren         | 4.90000000
# Deira City Centre Area| 4.90000000
# Beak Street, Soho   | 4.90000000
# Taman Impian Jaya Ancol, Ancol| 4.90000000
# Penjaringan         | 4.90000000
# Old Dutch Hospital, Fort| 4.90000000
# The Milk District   | 4.90000000
# Cengkareng          | 4.90000000
# ------------------------------------------------------------------

# %%
ax=zomato['Restaurant Name'].value_counts().head(15).plot.bar(figsize =(12,6))
ax.set_title("Top 15 Restarurents with maximum outlets")
for i in ax.patches:
    ax.annotate(i.get_height(), (i.get_x() * 1.005, i.get_height() * 1.005))

# %%
max_votes =zomato.Votes.sort_values(ascending=False).head(10)
zomato.loc[zomato['Votes'].isin(max_votes)][['Restaurant Name','Votes']]
zomato.loc[zomato['Votes'].isin(max_votes)][['Restaurant Name','Votes']].plot.bar(x='Restaurant Name', y='Votes',
figsize = (10,6), color='purple')

'''
We can see in the above graph that the restaurants with maximum number of outlets are not the one which 
have highest number of votes.The above list is totally different that our list of top 10 restaurants 
with maximum number of outlets.
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==216]
rest=data["Cuisines"].value_counts()
index=rest.index[0:10]

plt.title('top 10 cuisines present in restaurants in the USA')
plt.pie(rest[0:10],labels=index,autopct="%.2f%%")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
fre=data['City'].value_counts()
index=fre.index
plt.subplots(figsize=(12,7)) 
plt.scatter(index,fre)
plt.grid()
plt.title("Bubble chart")
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('zomato.csv',encoding='latin-1')
data=data[data['Country Code']==1]
fre=data['City'].value_counts()
index=fre.index
